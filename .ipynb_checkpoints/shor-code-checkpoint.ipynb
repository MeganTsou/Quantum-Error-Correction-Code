# %%
#import libraries
import qiskit
from qiskit import*
from qiskit import QuantumCircuit, execute, Aer
from qiskit.visualization import plot_histogram, plot_bloch_multivector
from math import sqrt, pi
from numpy.random import randint
import numpy as np
from qiskit.quantum_info import random_statevector, Statevector
import random

# %% [markdown]
# # Bit-flip Error on 1st qubit

# %%
q = QuantumRegister(9)
c = ClassicalRegister(9)
circuit = QuantumCircuit(q,c)

# %%
# Initialize q[0] to a random state
alpha = random.uniform(-1, 1)
beta = sqrt(1-alpha**2)*(-1)**(random.randrange(0,1,1))
circuit.initialize([alpha,beta], 0)
# Original state vector for all 9 qubits
simulator = Aer.get_backend('statevector_simulator')
job = execute(circuit, simulator)
result = job.result()
statevector = result.get_statevector()
plot_bloch_multivector(statevector)

# %%
circuit.measure(q[0],c[0])
simulator = Aer.get_backend('qasm_simulator')
job = execute(circuit, simulator,shots = 1024)
result = job.result()
counts = result.get_counts()
print(counts)
plot_histogram(counts)
# Out:
# {'000000000': 66, '000000001': 958}

# %%
q = QuantumRegister(9)
c = ClassicalRegister(9)
circuit = QuantumCircuit(q,c)
alpha = random.uniform(-1, 1)
beta = sqrt(1-alpha**2)*(-1)**(random.randrange(0,1,1))
circuit.initialize([alpha,beta], 0)

# %%
## Error occurs
circuit.x(q[0]) # Bit flip error

circuit.barrier(q)
print(circuit)
# Out:
#       ┌─────────────────────────────┐┌───┐┌───┐ ░
# q4_0: ┤ Initialize(0.86814,0.49633) ├┤ X ├┤ Z ├─░─
#       └─────────────────────────────┘└───┘└───┘ ░
# q4_1: ──────────────────────────────────────────░─
#                                                 ░
# q4_2: ──────────────────────────────────────────░─
#                                                 ░
# q4_3: ──────────────────────────────────────────░─
#                                                 ░
# q4_4: ──────────────────────────────────────────░─
#                                                 ░
# q4_5: ──────────────────────────────────────────░─
#                                                 ░
# q4_6: ──────────────────────────────────────────░─
#                                                 ░
# q4_7: ──────────────────────────────────────────░─
#                                                 ░
# q4_8: ──────────────────────────────────────────░─
#                                                 ░
# c1: 9/════════════════════════════════════════════

# %%
# State after error without Shor code
simulator = Aer.get_backend('statevector_simulator')
job = execute(circuit, simulator)
result = job.result()
statevector = result.get_statevector()
plot_bloch_multivector(statevector)

# %%
circuit.measure(q[0],c[0])
simulator = Aer.get_backend('qasm_simulator')
job = execute(circuit, simulator,shots = 1024)
result = job.result()
counts = result.get_counts()
print(counts)
plot_histogram(counts)
# Out:
# {'000000001': 744, '000000000': 280}

# %%
# Apply Shor code 
q = QuantumRegister(9)
c = ClassicalRegister(9)
circuit = QuantumCircuit(q,c)
alpha = random.uniform(-1, 1)
beta = sqrt(1-alpha**2)*(-1)**(random.randrange(0,1,1))
circuit.initialize([alpha,beta], 0)

# Encode
circuit.cx(q[0],q[3])
circuit.cx(q[0],q[6])

circuit.h(q[0])
circuit.h(q[3])
circuit.h(q[6])

circuit.cx(q[0],q[1])
circuit.cx(q[3],q[4])
circuit.cx(q[6],q[7])

circuit.cx(q[0],q[2])
circuit.cx(q[3],q[5])
circuit.cx(q[6],q[8])

circuit.barrier(q)

## Error occurs
circuit.x(q[0])#Bit flip error
circuit.z(q[0])#Phase flip error
circuit.barrier(q)

# Repair
circuit.cx(q[0],q[1])
circuit.cx(q[3],q[4])
circuit.cx(q[6],q[7])

circuit.cx(q[0],q[2])
circuit.cx(q[3],q[5])
circuit.cx(q[6],q[8])

circuit.ccx(q[1],q[2],q[0])
circuit.ccx(q[4],q[5],q[3])
circuit.ccx(q[8],q[7],q[6])

circuit.h(q[0])
circuit.h(q[3])
circuit.h(q[6])

circuit.cx(q[0],q[3])
circuit.cx(q[0],q[6])
circuit.ccx(q[6],q[3],q[0])
circuit.barrier(q)
print(circuit)
# Out:
#        ┌──────────────────────────────┐          ┌───┐           ░ ┌───┐┌───┐»
# q14_0: ┤ Initialize(-0.14126,0.98997) ├──■────■──┤ H ├──■────■───░─┤ X ├┤ Z ├»
#        └──────────────────────────────┘  │    │  └───┘┌─┴─┐  │   ░ └───┘└───┘»
# q14_1: ──────────────────────────────────┼────┼───────┤ X ├──┼───░───────────»
#                                          │    │       └───┘┌─┴─┐ ░           »
# q14_2: ──────────────────────────────────┼────┼────────────┤ X ├─░───────────»
#                                        ┌─┴─┐  │  ┌───┐     └───┘ ░           »
# q14_3: ────────────────────────────────┤ X ├──┼──┤ H ├──■────■───░───────────»
#                                        └───┘  │  └───┘┌─┴─┐  │   ░           »
# q14_4: ───────────────────────────────────────┼───────┤ X ├──┼───░───────────»
#                                               │       └───┘┌─┴─┐ ░           »
# q14_5: ───────────────────────────────────────┼────────────┤ X ├─░───────────»
#                                             ┌─┴─┐┌───┐     └───┘ ░           »
# q14_6: ─────────────────────────────────────┤ X ├┤ H ├──■────■───░───────────»
#                                             └───┘└───┘┌─┴─┐  │   ░           »
# q14_7: ───────────────────────────────────────────────┤ X ├──┼───░───────────»
#                                                       └───┘┌─┴─┐ ░           »
# q14_8: ────────────────────────────────────────────────────┤ X ├─░───────────»
#                                                            └───┘ ░           »
#  c2: 9/══════════════════════════════════════════════════════════════════════»
#                                                                              »
# «        ░           ┌───┐┌───┐          ┌───┐ ░
# «q14_0: ─░───■────■──┤ X ├┤ H ├──■────■──┤ X ├─░─
# «        ░ ┌─┴─┐  │  └─┬─┘└───┘  │    │  └─┬─┘ ░
# «q14_1: ─░─┤ X ├──┼────■─────────┼────┼────┼───░─
# «        ░ └───┘┌─┴─┐  │         │    │    │   ░
# «q14_2: ─░──────┤ X ├──■─────────┼────┼────┼───░─
# «        ░      └───┘┌───┐┌───┐┌─┴─┐  │    │   ░
# «q14_3: ─░───■────■──┤ X ├┤ H ├┤ X ├──┼────■───░─
# «        ░ ┌─┴─┐  │  └─┬─┘└───┘└───┘  │    │   ░
# «q14_4: ─░─┤ X ├──┼────■──────────────┼────┼───░─
# «        ░ └───┘┌─┴─┐  │              │    │   ░
# «q14_5: ─░──────┤ X ├──■──────────────┼────┼───░─
# «        ░      └───┘┌───┐┌───┐     ┌─┴─┐  │   ░
# «q14_6: ─░───■────■──┤ X ├┤ H ├─────┤ X ├──■───░─
# «        ░ ┌─┴─┐  │  └─┬─┘└───┘     └───┘      ░
# «q14_7: ─░─┤ X ├──┼────■───────────────────────░─
# «        ░ └───┘┌─┴─┐  │                       ░
# «q14_8: ─░──────┤ X ├──■───────────────────────░─
# «        ░      └───┘                          ░
# « c2: 9/═════════════════════════════════════════
# «

# %%
# State after correction circuit
simulator = Aer.get_backend('statevector_simulator')
job = execute(circuit, simulator)
result = job.result()
statevector = result.get_statevector()
plot_bloch_multivector(statevector)

# %%
circuit.measure(q[0],c[0])
simulator = Aer.get_backend('qasm_simulator')
job = execute(circuit, simulator,shots = 1024)
result = job.result()
counts = result.get_counts()
print(counts)
plot_histogram(counts)
# Out:
# {'000000000': 26, '000000001': 998}

# %% [markdown]
# # Bit-flip Error on 2nd qubit

# %%
q = QuantumRegister(9)
c = ClassicalRegister(9)
circuit = QuantumCircuit(q,c)
circuit.initialize([alpha,beta], 0)
## Error occurs
circuit.x(q[1]) # Bit flip error

circuit.barrier(q)
print(circuit)

# %%
# State after error without Shor code
simulator = Aer.get_backend('statevector_simulator')
job = execute(circuit, simulator)
result = job.result()
statevector = result.get_statevector()
plot_bloch_multivector(statevector)

# %%
circuit.measure(q[0],c[0])
simulator = Aer.get_backend('qasm_simulator')
job = execute(circuit, simulator,shots = 1024)
result = job.result()
counts = result.get_counts()
print(counts)
plot_histogram(counts)

# %%
# Apply Shor code 
q = QuantumRegister(9)
c = ClassicalRegister(9)
circuit = QuantumCircuit(q,c)
alpha = random.uniform(-1, 1)
beta = sqrt(1-alpha**2)*(-1)**(random.randrange(0,1,1))
circuit.initialize([alpha,beta], 0)

# Encode
circuit.cx(q[0],q[3])
circuit.cx(q[0],q[6])

circuit.h(q[0])
circuit.h(q[3])
circuit.h(q[6])

circuit.cx(q[0],q[1])
circuit.cx(q[3],q[4])
circuit.cx(q[6],q[7])

circuit.cx(q[0],q[2])
circuit.cx(q[3],q[5])
circuit.cx(q[6],q[8])

circuit.barrier(q)

## Error occurs
circuit.x(q[0])#Bit flip error
circuit.z(q[0])#Phase flip error
circuit.barrier(q)

# Repair
circuit.cx(q[0],q[1])
circuit.cx(q[3],q[4])
circuit.cx(q[6],q[7])

circuit.cx(q[0],q[2])
circuit.cx(q[3],q[5])
circuit.cx(q[6],q[8])

circuit.ccx(q[1],q[2],q[0])
circuit.ccx(q[4],q[5],q[3])
circuit.ccx(q[8],q[7],q[6])

circuit.h(q[0])
circuit.h(q[3])
circuit.h(q[6])

circuit.cx(q[0],q[3])
circuit.cx(q[0],q[6])
circuit.ccx(q[6],q[3],q[0])
circuit.barrier(q)

# %%
# State after correction circuit
simulator = Aer.get_backend('statevector_simulator')
job = execute(circuit, simulator)
result = job.result()
statevector = result.get_statevector()
plot_bloch_multivector(statevector)

# %%
circuit.measure(q[0],c[0])
simulator = Aer.get_backend('qasm_simulator')
job = execute(circuit, simulator,shots = 1024)
result = job.result()
counts = result.get_counts()
print(counts)
plot_histogram(counts)

# %% [markdown]
# # Bit-flip Error on 3rd qubit

# %%
q = QuantumRegister(9)
c = ClassicalRegister(9)
circuit = QuantumCircuit(q,c)
circuit.initialize([alpha,beta], 0)
## Error occurs
circuit.x(q[2]) # Bit flip error

circuit.barrier(q)
print(circuit)

# %%
# State after error without Shor code
simulator = Aer.get_backend('statevector_simulator')
job = execute(circuit, simulator)
result = job.result()
statevector = result.get_statevector()
plot_bloch_multivector(statevector)

# %%
circuit.measure(q[0],c[0])
simulator = Aer.get_backend('qasm_simulator')
job = execute(circuit, simulator,shots = 1024)
result = job.result()
counts = result.get_counts()
print(counts)
plot_histogram(counts)

# %%
# Apply Shor code 
q = QuantumRegister(9)
c = ClassicalRegister(9)
circuit = QuantumCircuit(q,c)
alpha = random.uniform(-1, 1)
beta = sqrt(1-alpha**2)*(-1)**(random.randrange(0,1,1))
circuit.initialize([alpha,beta], 0)

# Encode
circuit.cx(q[0],q[3])
circuit.cx(q[0],q[6])

circuit.h(q[0])
circuit.h(q[3])
circuit.h(q[6])

circuit.cx(q[0],q[1])
circuit.cx(q[3],q[4])
circuit.cx(q[6],q[7])

circuit.cx(q[0],q[2])
circuit.cx(q[3],q[5])
circuit.cx(q[6],q[8])

circuit.barrier(q)

## Error occurs
circuit.x(q[0])#Bit flip error
circuit.z(q[0])#Phase flip error
circuit.barrier(q)

# Repair
circuit.cx(q[0],q[1])
circuit.cx(q[3],q[4])
circuit.cx(q[6],q[7])

circuit.cx(q[0],q[2])
circuit.cx(q[3],q[5])
circuit.cx(q[6],q[8])

circuit.ccx(q[1],q[2],q[0])
circuit.ccx(q[4],q[5],q[3])
circuit.ccx(q[8],q[7],q[6])

circuit.h(q[0])
circuit.h(q[3])
circuit.h(q[6])

circuit.cx(q[0],q[3])
circuit.cx(q[0],q[6])
circuit.ccx(q[6],q[3],q[0])
circuit.barrier(q)

# %%
# State after correction circuit
simulator = Aer.get_backend('statevector_simulator')
job = execute(circuit, simulator)
result = job.result()
statevector = result.get_statevector()
plot_bloch_multivector(statevector)

# %%
circuit.measure(q[0],c[0])
simulator = Aer.get_backend('qasm_simulator')
job = execute(circuit, simulator,shots = 1024)
result = job.result()
counts = result.get_counts()
print(counts)
plot_histogram(counts)

# %% [markdown]
# # Bit-flip Error on 4th qubit

# %%
q = QuantumRegister(9)
c = ClassicalRegister(9)
circuit = QuantumCircuit(q,c)
circuit.initialize([alpha,beta], 0)
## Error occurs
circuit.x(q[3]) # Bit flip error

circuit.barrier(q)
print(circuit)

# %%
# State after error without Shor code
simulator = Aer.get_backend('statevector_simulator')
job = execute(circuit, simulator)
result = job.result()
statevector = result.get_statevector()
plot_bloch_multivector(statevector)

# %%
circuit.measure(q[0],c[0])
simulator = Aer.get_backend('qasm_simulator')
job = execute(circuit, simulator,shots = 1024)
result = job.result()
counts = result.get_counts()
print(counts)
plot_histogram(counts)

# %%
# Apply Shor code 
q = QuantumRegister(9)
c = ClassicalRegister(9)
circuit = QuantumCircuit(q,c)
alpha = random.uniform(-1, 1)
beta = sqrt(1-alpha**2)*(-1)**(random.randrange(0,1,1))
circuit.initialize([alpha,beta], 0)

# Encode
circuit.cx(q[0],q[3])
circuit.cx(q[0],q[6])

circuit.h(q[0])
circuit.h(q[3])
circuit.h(q[6])

circuit.cx(q[0],q[1])
circuit.cx(q[3],q[4])
circuit.cx(q[6],q[7])

circuit.cx(q[0],q[2])
circuit.cx(q[3],q[5])
circuit.cx(q[6],q[8])

circuit.barrier(q)

## Error occurs
circuit.x(q[0])#Bit flip error
circuit.z(q[0])#Phase flip error
circuit.barrier(q)

# Repair
circuit.cx(q[0],q[1])
circuit.cx(q[3],q[4])
circuit.cx(q[6],q[7])

circuit.cx(q[0],q[2])
circuit.cx(q[3],q[5])
circuit.cx(q[6],q[8])

circuit.ccx(q[1],q[2],q[0])
circuit.ccx(q[4],q[5],q[3])
circuit.ccx(q[8],q[7],q[6])

circuit.h(q[0])
circuit.h(q[3])
circuit.h(q[6])

circuit.cx(q[0],q[3])
circuit.cx(q[0],q[6])
circuit.ccx(q[6],q[3],q[0])
circuit.barrier(q)

# %%
# State after correction circuit
simulator = Aer.get_backend('statevector_simulator')
job = execute(circuit, simulator)
result = job.result()
statevector = result.get_statevector()
plot_bloch_multivector(statevector)

# %%
circuit.measure(q[0],c[0])
simulator = Aer.get_backend('qasm_simulator')
job = execute(circuit, simulator,shots = 1024)
result = job.result()
counts = result.get_counts()
print(counts)
plot_histogram(counts)

# %% [markdown]
# # Bit-flip Error on 5th qubit

# %%
q = QuantumRegister(9)
c = ClassicalRegister(9)
circuit = QuantumCircuit(q,c)
circuit.initialize([alpha,beta], 0)
## Error occurs
circuit.x(q[4]) # Bit flip error

circuit.barrier(q)
print(circuit)

# %%
# State after error without Shor code
simulator = Aer.get_backend('statevector_simulator')
job = execute(circuit, simulator)
result = job.result()
statevector = result.get_statevector()
plot_bloch_multivector(statevector)

# %%
circuit.measure(q[0],c[0])
simulator = Aer.get_backend('qasm_simulator')
job = execute(circuit, simulator,shots = 1024)
result = job.result()
counts = result.get_counts()
print(counts)
plot_histogram(counts)

# %%
# Apply Shor code 
q = QuantumRegister(9)
c = ClassicalRegister(9)
circuit = QuantumCircuit(q,c)
alpha = random.uniform(-1, 1)
beta = sqrt(1-alpha**2)*(-1)**(random.randrange(0,1,1))
circuit.initialize([alpha,beta], 0)

# Encode
circuit.cx(q[0],q[3])
circuit.cx(q[0],q[6])

circuit.h(q[0])
circuit.h(q[3])
circuit.h(q[6])

circuit.cx(q[0],q[1])
circuit.cx(q[3],q[4])
circuit.cx(q[6],q[7])

circuit.cx(q[0],q[2])
circuit.cx(q[3],q[5])
circuit.cx(q[6],q[8])

circuit.barrier(q)

## Error occurs
circuit.x(q[0])#Bit flip error
circuit.z(q[0])#Phase flip error
circuit.barrier(q)

# Repair
circuit.cx(q[0],q[1])
circuit.cx(q[3],q[4])
circuit.cx(q[6],q[7])

circuit.cx(q[0],q[2])
circuit.cx(q[3],q[5])
circuit.cx(q[6],q[8])

circuit.ccx(q[1],q[2],q[0])
circuit.ccx(q[4],q[5],q[3])
circuit.ccx(q[8],q[7],q[6])

circuit.h(q[0])
circuit.h(q[3])
circuit.h(q[6])

circuit.cx(q[0],q[3])
circuit.cx(q[0],q[6])
circuit.ccx(q[6],q[3],q[0])
circuit.barrier(q)

# %%
# State after correction circuit
simulator = Aer.get_backend('statevector_simulator')
job = execute(circuit, simulator)
result = job.result()
statevector = result.get_statevector()
plot_bloch_multivector(statevector)

# %%
circuit.measure(q[0],c[0])
simulator = Aer.get_backend('qasm_simulator')
job = execute(circuit, simulator,shots = 1024)
result = job.result()
counts = result.get_counts()
print(counts)
plot_histogram(counts)

# %% [markdown]
# # Bit-flip Error on 6th qubit

# %%
q = QuantumRegister(9)
c = ClassicalRegister(9)
circuit = QuantumCircuit(q,c)
circuit.initialize([alpha,beta], 0)
## Error occurs
circuit.x(q[5]) # Bit flip error

circuit.barrier(q)
print(circuit)

# %%
# State after error without Shor code
simulator = Aer.get_backend('statevector_simulator')
job = execute(circuit, simulator)
result = job.result()
statevector = result.get_statevector()
plot_bloch_multivector(statevector)

# %%
circuit.measure(q[0],c[0])
simulator = Aer.get_backend('qasm_simulator')
job = execute(circuit, simulator,shots = 1024)
result = job.result()
counts = result.get_counts()
print(counts)
plot_histogram(counts)

# %%
# Apply Shor code 
q = QuantumRegister(9)
c = ClassicalRegister(9)
circuit = QuantumCircuit(q,c)
alpha = random.uniform(-1, 1)
beta = sqrt(1-alpha**2)*(-1)**(random.randrange(0,1,1))
circuit.initialize([alpha,beta], 0)

# Encode
circuit.cx(q[0],q[3])
circuit.cx(q[0],q[6])

circuit.h(q[0])
circuit.h(q[3])
circuit.h(q[6])

circuit.cx(q[0],q[1])
circuit.cx(q[3],q[4])
circuit.cx(q[6],q[7])

circuit.cx(q[0],q[2])
circuit.cx(q[3],q[5])
circuit.cx(q[6],q[8])

circuit.barrier(q)

## Error occurs
circuit.x(q[0])#Bit flip error
circuit.z(q[0])#Phase flip error
circuit.barrier(q)

# Repair
circuit.cx(q[0],q[1])
circuit.cx(q[3],q[4])
circuit.cx(q[6],q[7])

circuit.cx(q[0],q[2])
circuit.cx(q[3],q[5])
circuit.cx(q[6],q[8])

circuit.ccx(q[1],q[2],q[0])
circuit.ccx(q[4],q[5],q[3])
circuit.ccx(q[8],q[7],q[6])

circuit.h(q[0])
circuit.h(q[3])
circuit.h(q[6])

circuit.cx(q[0],q[3])
circuit.cx(q[0],q[6])
circuit.ccx(q[6],q[3],q[0])
circuit.barrier(q)

# %%
# State after correction circuit
simulator = Aer.get_backend('statevector_simulator')
job = execute(circuit, simulator)
result = job.result()
statevector = result.get_statevector()
plot_bloch_multivector(statevector)

# %%
circuit.measure(q[0],c[0])
simulator = Aer.get_backend('qasm_simulator')
job = execute(circuit, simulator,shots = 1024)
result = job.result()
counts = result.get_counts()
print(counts)
plot_histogram(counts)

# %% [markdown]
# # Bit-flip Error on 7th qubit

# %%
q = QuantumRegister(9)
c = ClassicalRegister(9)
circuit = QuantumCircuit(q,c)
circuit.initialize([alpha,beta], 0)
## Error occurs
circuit.x(q[6]) # Bit flip error

circuit.barrier(q)
print(circuit)

# %%
# State after error without Shor code
simulator = Aer.get_backend('statevector_simulator')
job = execute(circuit, simulator)
result = job.result()
statevector = result.get_statevector()
plot_bloch_multivector(statevector)

# %%
circuit.measure(q[0],c[0])
simulator = Aer.get_backend('qasm_simulator')
job = execute(circuit, simulator,shots = 1024)
result = job.result()
counts = result.get_counts()
print(counts)
plot_histogram(counts)

# %%
# Apply Shor code 
q = QuantumRegister(9)
c = ClassicalRegister(9)
circuit = QuantumCircuit(q,c)
alpha = random.uniform(-1, 1)
beta = sqrt(1-alpha**2)*(-1)**(random.randrange(0,1,1))
circuit.initialize([alpha,beta], 0)

# Encode
circuit.cx(q[0],q[3])
circuit.cx(q[0],q[6])

circuit.h(q[0])
circuit.h(q[3])
circuit.h(q[6])

circuit.cx(q[0],q[1])
circuit.cx(q[3],q[4])
circuit.cx(q[6],q[7])

circuit.cx(q[0],q[2])
circuit.cx(q[3],q[5])
circuit.cx(q[6],q[8])

circuit.barrier(q)

## Error occurs
circuit.x(q[0])#Bit flip error
circuit.z(q[0])#Phase flip error
circuit.barrier(q)

# Repair
circuit.cx(q[0],q[1])
circuit.cx(q[3],q[4])
circuit.cx(q[6],q[7])

circuit.cx(q[0],q[2])
circuit.cx(q[3],q[5])
circuit.cx(q[6],q[8])

circuit.ccx(q[1],q[2],q[0])
circuit.ccx(q[4],q[5],q[3])
circuit.ccx(q[8],q[7],q[6])

circuit.h(q[0])
circuit.h(q[3])
circuit.h(q[6])

circuit.cx(q[0],q[3])
circuit.cx(q[0],q[6])
circuit.ccx(q[6],q[3],q[0])
circuit.barrier(q)

# %%
# State after correction circuit
simulator = Aer.get_backend('statevector_simulator')
job = execute(circuit, simulator)
result = job.result()
statevector = result.get_statevector()
plot_bloch_multivector(statevector)

# %%
circuit.measure(q[0],c[0])
simulator = Aer.get_backend('qasm_simulator')
job = execute(circuit, simulator,shots = 1024)
result = job.result()
counts = result.get_counts()
print(counts)
plot_histogram(counts)

# %% [markdown]
# # Bit-flip Error on 8th qubit

# %%
q = QuantumRegister(9)
c = ClassicalRegister(9)
circuit = QuantumCircuit(q,c)
circuit.initialize([alpha,beta], 0)
## Error occurs
circuit.x(q[7]) # Bit flip error

circuit.barrier(q)
print(circuit)

# %%
# State after error without Shor code
simulator = Aer.get_backend('statevector_simulator')
job = execute(circuit, simulator)
result = job.result()
statevector = result.get_statevector()
plot_bloch_multivector(statevector)

# %%
circuit.measure(q[0],c[0])
simulator = Aer.get_backend('qasm_simulator')
job = execute(circuit, simulator,shots = 1024)
result = job.result()
counts = result.get_counts()
print(counts)
plot_histogram(counts)

# %%
# Apply Shor code 
q = QuantumRegister(9)
c = ClassicalRegister(9)
circuit = QuantumCircuit(q,c)
alpha = random.uniform(-1, 1)
beta = sqrt(1-alpha**2)*(-1)**(random.randrange(0,1,1))
circuit.initialize([alpha,beta], 0)

# Encode
circuit.cx(q[0],q[3])
circuit.cx(q[0],q[6])

circuit.h(q[0])
circuit.h(q[3])
circuit.h(q[6])

circuit.cx(q[0],q[1])
circuit.cx(q[3],q[4])
circuit.cx(q[6],q[7])

circuit.cx(q[0],q[2])
circuit.cx(q[3],q[5])
circuit.cx(q[6],q[8])

circuit.barrier(q)

## Error occurs
circuit.x(q[0])#Bit flip error
circuit.z(q[0])#Phase flip error
circuit.barrier(q)

# Repair
circuit.cx(q[0],q[1])
circuit.cx(q[3],q[4])
circuit.cx(q[6],q[7])

circuit.cx(q[0],q[2])
circuit.cx(q[3],q[5])
circuit.cx(q[6],q[8])

circuit.ccx(q[1],q[2],q[0])
circuit.ccx(q[4],q[5],q[3])
circuit.ccx(q[8],q[7],q[6])

circuit.h(q[0])
circuit.h(q[3])
circuit.h(q[6])

circuit.cx(q[0],q[3])
circuit.cx(q[0],q[6])
circuit.ccx(q[6],q[3],q[0])
circuit.barrier(q)

# %%
# State after correction circuit
simulator = Aer.get_backend('statevector_simulator')
job = execute(circuit, simulator)
result = job.result()
statevector = result.get_statevector()
plot_bloch_multivector(statevector)

# %%
circuit.measure(q[0],c[0])
simulator = Aer.get_backend('qasm_simulator')
job = execute(circuit, simulator,shots = 1024)
result = job.result()
counts = result.get_counts()
print(counts)
plot_histogram(counts)

# %% [markdown]
# # Bit-flip Error on 9th qubit

# %%
q = QuantumRegister(9)
c = ClassicalRegister(9)
circuit = QuantumCircuit(q,c)
circuit.initialize([alpha,beta], 0)
## Error occurs
circuit.x(q[8]) # Bit flip error

circuit.barrier(q)
print(circuit)

# %%
# State after error without Shor code
simulator = Aer.get_backend('statevector_simulator')
job = execute(circuit, simulator)
result = job.result()
statevector = result.get_statevector()
plot_bloch_multivector(statevector)

# %%
circuit.measure(q[0],c[0])
simulator = Aer.get_backend('qasm_simulator')
job = execute(circuit, simulator,shots = 1024)
result = job.result()
counts = result.get_counts()
print(counts)
plot_histogram(counts)

# %%
# Apply Shor code 
q = QuantumRegister(9)
c = ClassicalRegister(9)
circuit = QuantumCircuit(q,c)
alpha = random.uniform(-1, 1)
beta = sqrt(1-alpha**2)*(-1)**(random.randrange(0,1,1))
circuit.initialize([alpha,beta], 0)

# Encode
circuit.cx(q[0],q[3])
circuit.cx(q[0],q[6])

circuit.h(q[0])
circuit.h(q[3])
circuit.h(q[6])

circuit.cx(q[0],q[1])
circuit.cx(q[3],q[4])
circuit.cx(q[6],q[7])

circuit.cx(q[0],q[2])
circuit.cx(q[3],q[5])
circuit.cx(q[6],q[8])

circuit.barrier(q)

## Error occurs
circuit.x(q[0])#Bit flip error
circuit.z(q[0])#Phase flip error
circuit.barrier(q)

# Repair
circuit.cx(q[0],q[1])
circuit.cx(q[3],q[4])
circuit.cx(q[6],q[7])

circuit.cx(q[0],q[2])
circuit.cx(q[3],q[5])
circuit.cx(q[6],q[8])

circuit.ccx(q[1],q[2],q[0])
circuit.ccx(q[4],q[5],q[3])
circuit.ccx(q[8],q[7],q[6])

circuit.h(q[0])
circuit.h(q[3])
circuit.h(q[6])

circuit.cx(q[0],q[3])
circuit.cx(q[0],q[6])
circuit.ccx(q[6],q[3],q[0])
circuit.barrier(q)

# %%
# State after correction circuit
simulator = Aer.get_backend('statevector_simulator')
job = execute(circuit, simulator)
result = job.result()
statevector = result.get_statevector()
plot_bloch_multivector(statevector)

# %%
circuit.measure(q[0],c[0])
simulator = Aer.get_backend('qasm_simulator')
job = execute(circuit, simulator,shots = 1024)
result = job.result()
counts = result.get_counts()
print(counts)
plot_histogram(counts)

# %% [markdown]
# # Phase-flip Error on 1st group

# %%
q = QuantumRegister(9)
c = ClassicalRegister(9)
circuit = QuantumCircuit(q,c)
circuit.initialize([alpha,beta], 0)
## Error occurs
circuit.z(q[0]) # Bit flip error

circuit.barrier(q)
print(circuit)

# %%
# State after error without Shor code
simulator = Aer.get_backend('statevector_simulator')
job = execute(circuit, simulator)
result = job.result()
statevector = result.get_statevector()
plot_bloch_multivector(statevector)

# %%
circuit.measure(q[0],c[0])
simulator = Aer.get_backend('qasm_simulator')
job = execute(circuit, simulator,shots = 1024)
result = job.result()
counts = result.get_counts()
print(counts)
plot_histogram(counts)

# %%
# Apply Shor code 
q = QuantumRegister(9)
c = ClassicalRegister(9)
circuit = QuantumCircuit(q,c)
alpha = random.uniform(-1, 1)
beta = sqrt(1-alpha**2)*(-1)**(random.randrange(0,1,1))
circuit.initialize([alpha,beta], 0)

# Encode
circuit.cx(q[0],q[3])
circuit.cx(q[0],q[6])

circuit.h(q[0])
circuit.h(q[3])
circuit.h(q[6])

circuit.cx(q[0],q[1])
circuit.cx(q[3],q[4])
circuit.cx(q[6],q[7])

circuit.cx(q[0],q[2])
circuit.cx(q[3],q[5])
circuit.cx(q[6],q[8])

circuit.barrier(q)

## Error occurs
circuit.x(q[0])#Bit flip error
circuit.z(q[0])#Phase flip error
circuit.barrier(q)

# Repair
circuit.cx(q[0],q[1])
circuit.cx(q[3],q[4])
circuit.cx(q[6],q[7])

circuit.cx(q[0],q[2])
circuit.cx(q[3],q[5])
circuit.cx(q[6],q[8])

circuit.ccx(q[1],q[2],q[0])
circuit.ccx(q[4],q[5],q[3])
circuit.ccx(q[8],q[7],q[6])

circuit.h(q[0])
circuit.h(q[3])
circuit.h(q[6])

circuit.cx(q[0],q[3])
circuit.cx(q[0],q[6])
circuit.ccx(q[6],q[3],q[0])
circuit.barrier(q)

# %%
# State after correction circuit
simulator = Aer.get_backend('statevector_simulator')
job = execute(circuit, simulator)
result = job.result()
statevector = result.get_statevector()
plot_bloch_multivector(statevector)

# %%
circuit.measure(q[0],c[0])
simulator = Aer.get_backend('qasm_simulator')
job = execute(circuit, simulator,shots = 1024)
result = job.result()
counts = result.get_counts()
print(counts)
plot_histogram(counts)

# %% [markdown]
# # Phase-flip Error on 2nd group

# %%
q = QuantumRegister(9)
c = ClassicalRegister(9)
circuit = QuantumCircuit(q,c)
circuit.initialize([alpha,beta], 0)
## Error occurs
circuit.z(q[3]) # Bit flip error

circuit.barrier(q)
print(circuit)

# %%
# State after error without Shor code
simulator = Aer.get_backend('statevector_simulator')
job = execute(circuit, simulator)
result = job.result()
statevector = result.get_statevector()
plot_bloch_multivector(statevector)

# %%
circuit.measure(q[0],c[0])
simulator = Aer.get_backend('qasm_simulator')
job = execute(circuit, simulator,shots = 1024)
result = job.result()
counts = result.get_counts()
print(counts)
plot_histogram(counts)

# %%
# Apply Shor code 
q = QuantumRegister(9)
c = ClassicalRegister(9)
circuit = QuantumCircuit(q,c)
alpha = random.uniform(-1, 1)
beta = sqrt(1-alpha**2)*(-1)**(random.randrange(0,1,1))
circuit.initialize([alpha,beta], 0)

# Encode
circuit.cx(q[0],q[3])
circuit.cx(q[0],q[6])

circuit.h(q[0])
circuit.h(q[3])
circuit.h(q[6])

circuit.cx(q[0],q[1])
circuit.cx(q[3],q[4])
circuit.cx(q[6],q[7])

circuit.cx(q[0],q[2])
circuit.cx(q[3],q[5])
circuit.cx(q[6],q[8])

circuit.barrier(q)

## Error occurs
circuit.x(q[0])#Bit flip error
circuit.z(q[0])#Phase flip error
circuit.barrier(q)

# Repair
circuit.cx(q[0],q[1])
circuit.cx(q[3],q[4])
circuit.cx(q[6],q[7])

circuit.cx(q[0],q[2])
circuit.cx(q[3],q[5])
circuit.cx(q[6],q[8])

circuit.ccx(q[1],q[2],q[0])
circuit.ccx(q[4],q[5],q[3])
circuit.ccx(q[8],q[7],q[6])

circuit.h(q[0])
circuit.h(q[3])
circuit.h(q[6])

circuit.cx(q[0],q[3])
circuit.cx(q[0],q[6])
circuit.ccx(q[6],q[3],q[0])
circuit.barrier(q)

# %%
# State after correction circuit
simulator = Aer.get_backend('statevector_simulator')
job = execute(circuit, simulator)
result = job.result()
statevector = result.get_statevector()
plot_bloch_multivector(statevector)

# %%
circuit.measure(q[0],c[0])
simulator = Aer.get_backend('qasm_simulator')
job = execute(circuit, simulator,shots = 1024)
result = job.result()
counts = result.get_counts()
print(counts)
plot_histogram(counts)

# %% [markdown]
# # Phase-flip Error on 3rd group

# %%
q = QuantumRegister(9)
c = ClassicalRegister(9)
circuit = QuantumCircuit(q,c)
circuit.initialize([alpha,beta], 0)
## Error occurs
circuit.z(q[6]) # Bit flip error

circuit.barrier(q)
print(circuit)

# %%
# State after error without Shor code
simulator = Aer.get_backend('statevector_simulator')
job = execute(circuit, simulator)
result = job.result()
statevector = result.get_statevector()
plot_bloch_multivector(statevector)

# %%
circuit.measure(q[0],c[0])
simulator = Aer.get_backend('qasm_simulator')
job = execute(circuit, simulator,shots = 1024)
result = job.result()
counts = result.get_counts()
print(counts)
plot_histogram(counts)

# %%
# Apply Shor code 
q = QuantumRegister(9)
c = ClassicalRegister(9)
circuit = QuantumCircuit(q,c)
alpha = random.uniform(-1, 1)
beta = sqrt(1-alpha**2)*(-1)**(random.randrange(0,1,1))
circuit.initialize([alpha,beta], 0)

# Encode
circuit.cx(q[0],q[3])
circuit.cx(q[0],q[6])

circuit.h(q[0])
circuit.h(q[3])
circuit.h(q[6])

circuit.cx(q[0],q[1])
circuit.cx(q[3],q[4])
circuit.cx(q[6],q[7])

circuit.cx(q[0],q[2])
circuit.cx(q[3],q[5])
circuit.cx(q[6],q[8])

circuit.barrier(q)

## Error occurs
circuit.x(q[0])#Bit flip error
circuit.z(q[0])#Phase flip error
circuit.barrier(q)

# Repair
circuit.cx(q[0],q[1])
circuit.cx(q[3],q[4])
circuit.cx(q[6],q[7])

circuit.cx(q[0],q[2])
circuit.cx(q[3],q[5])
circuit.cx(q[6],q[8])

circuit.ccx(q[1],q[2],q[0])
circuit.ccx(q[4],q[5],q[3])
circuit.ccx(q[8],q[7],q[6])

circuit.h(q[0])
circuit.h(q[3])
circuit.h(q[6])

circuit.cx(q[0],q[3])
circuit.cx(q[0],q[6])
circuit.ccx(q[6],q[3],q[0])
circuit.barrier(q)

# %%
# State after correction circuit
simulator = Aer.get_backend('statevector_simulator')
job = execute(circuit, simulator)
result = job.result()
statevector = result.get_statevector()
plot_bloch_multivector(statevector)

# %%
circuit.measure(q[0],c[0])
simulator = Aer.get_backend('qasm_simulator')
job = execute(circuit, simulator,shots = 1024)
result = job.result()
counts = result.get_counts()
print(counts)
plot_histogram(counts)
